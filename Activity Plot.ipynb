# %%
import Th_function as th

# %% [markdown]
# # Pace Data

# %% [markdown]
# ## Thorium series

# %%
th.pace_plot([3,4])
th.pace_compare([3,4])

# %%
th.pace_plot([4,5])
th.pace_compare([4,5])

# %%
th.pace_plot([5,6])
th.pace_compare([5,6])

# %%
th.pace_plot([6,7])
th.pace_compare([6,7])

# %%
th.pace_plot([7,8])
th.pace_compare([7,8])

# %% [markdown]
# ## Uranium series

# %%
th.pace_plot([9,10])
th.pace_compare([9,10])

# %%
th.pace_plot([10,11])
th.pace_compare([10,11])

# %%
th.pace_plot([11,12])
th.pace_compare([11,12])

# %%
th.pace_plot([12,13])
th.pace_compare([12,13])

# %%
th.pace_plot([13,14])
th.pace_compare([13,14])

# %% [markdown]
# # NAREL DATA

# %% [markdown]
# ## Thorium Series

# %%
th.narel_plot([0,1])
th.narel_compare([0,1])

# %%
th.narel_plot([1,2])
th.narel_compare([1,2])

# %%
th.narel_plot([2,3])
th.narel_compare([2,3])

# %%
th.narel_plot([3,4])
th.narel_compare([3,4])

# %%
th.narel_plot([4,5])
th.narel_compare([4,5])

# %% [markdown]
# ## Uranium Series

# %%
th.narel_plot([6,7])
th.narel_compare([6,7])

# %%
th.narel_plot([7,8])
th.narel_compare([7,8])

# %%
th.narel_plot([8,9])
th.narel_compare([8,9])

# %%
th.narel_plot([9,10])
th.narel_compare([9,10])

# %%
th.narel_plot([10,11])
th.narel_compare([10,11])

# %%
th.narel_plot([11,12])
th.narel_compare([11,12])

# %%
th.narel_plot([12,13])
th.narel_compare([12,13])
