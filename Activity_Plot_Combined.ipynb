# %%
import Th_function as th
import numpy as np

# %% [markdown]
# # Overall without Background

# %%
th.combined_plot(th.filt(th.combined[:-1],1))

# %% [markdown]
# # Thorium Series

# %% [markdown]
# ### With Background

# %%
th.combined_plot(th.filt(th.combined[:6],0))

# %% [markdown]
# ### Without Background

# %%
th.combined_plot(th.filt(th.combined[:6],1))

# %% [markdown]
# # Uranium Series

# %% [markdown]
# ### With Background

# %%
th.combined_plot(th.filt(th.combined[6:14],0))

# %% [markdown]
# ### Without Background

# %%
th.combined_plot(th.filt(th.combined[6:14],1))

# %%
th.combined_compare(th.filt([th.data_combine(n) for n in ["Thorium-230","Radium-226"]],1))

# %%
th.combined_compare(th.filt([th.data_combine(n) for n in ["Radium-226","Lead-214"]],1))

# %%
th.combined_compare(th.filt([th.data_combine(n) for n in ["Radium-226","Lead-210"]],1))

# %% [markdown]
# # U235 +Th227+K40

# %% [markdown]
# ### With Background

# %%
th.combined_plot(th.filt(th.combined[-4:-1],0))

# %%
th.combined_plot(th.filt([th.combined[-1]],0))

# %% [markdown]
# ### Without Background

# %%
th.combined_plot(th.filt(th.combined[-4:-1],1))

# %%
A= np.array([y for y in th.combined[-1][1:] if float(y[4]) >= 19 and float(y[4]) > float(y[5]) and float(y[4]) > float(y[6]) and y[-1] is not "R"])         
th.combined_plot([A])
